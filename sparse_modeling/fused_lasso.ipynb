# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt

import fused_lasso

# %%
img = imageio.imread("images/test1.png")

# %%
plt.imshow(-1img, cmap="gray")

# %%
np.random.seed(0)
# Add noise 
noise = np.random.normal(size=img.shape, loc=0., scale=20.)

noisy_img = img + noise
plt.imshow(-noisy_img, cmap="gray")

# %%
l = fused_lasso.FusedLasso()

# %%
result = l.fit_transform(-1 *noisy_img)
# Out:
# break at iter=843

# %%
plt.imshow(-1 * result, cmap="gray")

# %%
l2 = fused_lasso.FusedLasso(lambda_= 1)
result2 = l2.fit_transform(noisy_img)
plt.imshow(result2, cmap="gray")
# Out:
# break at iter=389
